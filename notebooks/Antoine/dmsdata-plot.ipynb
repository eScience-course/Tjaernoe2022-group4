# %%
import xarray as xr
import s3fs
import matplotlib.pyplot as plt
import pandas as pd
from dask.diagnostics import ProgressBar
import cartopy.crs as ccrs
import numpy as np
import pandas as pd
s3 = s3fs.S3FileSystem(key="K1CQ7M1DMTLUFK182APD", secret="3JuZAQm5I03jtpijCpHOdkAsJDNLNfZxBpM15Pi0", client_kwargs=dict(endpoint_url="https://rgw.met.no"))

# %%
fig, ax = plt.subplots(figsize=(10,10),
                       subplot_kw={'projection':ccrs.NorthPolarStereo()
                       # subplot_kw={'projection':ccrs.PlateCarree()
                                  })
# .drop_vars(['longitude','longitude'])
ds.dms.isel(period=30,year=0).plot.pcolormesh(
    ax = ax,
    cbar_kwargs={ 'orientation':'vertical', 'shrink':.8},
    transform=ccrs.PlateCarree(),
    robust=True
    # transform=ccrs.AlbersEqualArea(),
    # levels=10,
        )
ax.gridlines(draw_labels=True)
ax.coastlines()
fig.tight_layout()

# %% [markdown]
# ## DMS Data

# %%
s3.ls('escience2022/Antoine/Satellite_Arctic_DMS')
# Out:
# ['escience2022/Antoine/Satellite_Arctic_DMS/dms_gsm_A2003_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/dms_gsm_A2004_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/dms_gsm_A2005_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/dms_gsm_A2006_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/dms_gsm_A2007_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/dms_gsm_A2008_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/dms_gsm_A2009_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/dms_gsm_A2010_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/dms_gsm_A2011_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/dms_gsm_A2012_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/dms_gsm_A2013_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/dms_gsm_A2014_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/dms_gsm_A2015_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/dms_gsm_A2016_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/dms_gsm_S1998_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/dms_gsm_S1999_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/dms_gsm_S2000_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/dms_gsm_S2001_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/dms_gsm_S2002_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/dms_gsm_S2003_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/dms_gsm_S2004_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/dms_gsm_S2005_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/dms_gsm_S2006_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/dms_gsm_S2007_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/dmspt_gsm_A2003_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/dmspt_gsm_A2004_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/dmspt_gsm_A2005_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/dmspt_gsm_A2006_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/dmspt_gsm_A2007_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/dmspt_gsm_A2008_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/dmspt_gsm_A2009_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/dmspt_gsm_A2010_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/dmspt_gsm_A2011_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/dmspt_gsm_A2012_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/dmspt_gsm_A2013_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/dmspt_gsm_A2014_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/dmspt_gsm_A2015_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/dmspt_gsm_A2016_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/dmspt_gsm_S1998_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/dmspt_gsm_S1999_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/dmspt_gsm_S2000_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/dmspt_gsm_S2001_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/dmspt_gsm_S2002_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/dmspt_gsm_S2003_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/dmspt_gsm_S2004_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/dmspt_gsm_S2005_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/dmspt_gsm_S2006_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/dmspt_gsm_S2007_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_L11_W97_CLIMdms_A2003_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_L11_W97_CLIMdms_A2004_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_L11_W97_CLIMdms_A2005_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_L11_W97_CLIMdms_A2006_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_L11_W97_CLIMdms_A2007_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_L11_W97_CLIMdms_A2008_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_L11_W97_CLIMdms_A2009_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_L11_W97_CLIMdms_A2010_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_L11_W97_CLIMdms_A2011_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_L11_W97_CLIMdms_A2012_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_L11_W97_CLIMdms_A2013_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_L11_W97_CLIMdms_A2014_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_L11_W97_CLIMdms_A2015_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_L11_W97_CLIMdms_A2016_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_L11_W97_CLIMdms_S1998_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_L11_W97_CLIMdms_S1999_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_L11_W97_CLIMdms_S2000_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_L11_W97_CLIMdms_S2001_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_L11_W97_CLIMdms_S2002_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_L11_W97_CLIMdms_S2003_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_L11_W97_CLIMdms_S2004_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_L11_W97_CLIMdms_S2005_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_L11_W97_CLIMdms_S2006_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_L11_W97_CLIMdms_S2007_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_N00GBC_A2003_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_N00GBC_A2004_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_N00GBC_A2005_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_N00GBC_A2006_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_N00GBC_A2007_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_N00GBC_A2008_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_N00GBC_A2009_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_N00GBC_A2010_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_N00GBC_A2011_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_N00GBC_A2012_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_N00GBC_A2013_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_N00GBC_A2014_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_N00GBC_A2015_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_N00GBC_A2016_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_N00GBC_S1998_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_N00GBC_S1999_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_N00GBC_S2000_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_N00GBC_S2001_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_N00GBC_S2002_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_N00GBC_S2003_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_N00GBC_S2004_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_N00GBC_S2005_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_N00GBC_S2006_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_N00GBC_S2007_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_W97_A2003_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_W97_A2004_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_W97_A2005_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_W97_A2006_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_W97_A2007_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_W97_A2008_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_W97_A2009_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_W97_A2010_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_W97_A2011_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_W97_A2012_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_W97_A2013_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_W97_A2014_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_W97_A2015_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_W97_A2016_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_W97_CLIMdms_A2003_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_W97_CLIMdms_A2004_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_W97_CLIMdms_A2005_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_W97_CLIMdms_A2006_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_W97_CLIMdms_A2007_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_W97_CLIMdms_A2008_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_W97_CLIMdms_A2009_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_W97_CLIMdms_A2010_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_W97_CLIMdms_A2011_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_W97_CLIMdms_A2012_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_W97_CLIMdms_A2013_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_W97_CLIMdms_A2014_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_W97_CLIMdms_A2015_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_W97_CLIMdms_A2016_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_W97_CLIMdms_S1998_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_W97_CLIMdms_S1999_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_W97_CLIMdms_S2000_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_W97_CLIMdms_S2001_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_W97_CLIMdms_S2002_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_W97_CLIMdms_S2003_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_W97_CLIMdms_S2004_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_W97_CLIMdms_S2005_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_W97_CLIMdms_S2006_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_W97_CLIMdms_S2007_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_W97_S1998_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_W97_S1999_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_W97_S2000_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_W97_S2001_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_W97_S2002_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_W97_S2003_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_W97_S2004_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_W97_S2005_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_W97_S2006_8D_28km.nc',
#  'escience2022/Antoine/Satellite_Arctic_DMS/fdms_gsm_W97_S2007_8D_28km.nc']

# %% [markdown]
# ## Dask with gateway

# %%
from dask.distributed import Client
from dask_gateway import Gateway
gateway = Gateway()

# %%
cluster = gateway.new_cluster(worker_memory=2, worker_cores=1)
cluster.scale(8)
client = Client(cluster) # create a dask Gateway cluster
cluster
# Out:
# VBox(children=(HTML(value='<h2>GatewayCluster</h2>'), HBox(children=(HTML(value='\n<div>\n<style scoped>\n    …

# %%
if cluster:
    client = Client(cluster) # create a dask Gateway cluster
else:
    client = Client()   # create a local dask cluster on the machine.
client
# Out:
# <Client: 'tls://10.244.5.19:8786' processes=8 threads=8, memory=16.00 GiB>

# %%
#closing open 
# clusters=gateway.list_clusters()
# print(clusters )
# for cluster in clusters :
#     cluster= gateway.connect(cluster.name)
#     print(cluster)
#     client = Client(cluster)
#     client.close()
#     cluster.shutdown()

# %%
# To close at end of session
client.close()

# %%
cluster.shutdown()

# %% [markdown]
# ## Open files

# %%
#### single file
# file = 's3://escience2022/Antoine/Satellite_Arctic_DMS/dms_gsm_A2010_8D_28km.nc'
# ds = xr.open_dataset(s3.open(file))

### multiple files
s3files = 's3://escience2022/Antoine/Satellite_Arctic_DMS/dms_gsm_A*_8D_28km.nc'
remote_files = s3.glob(s3files)
fileset = [s3.open(file) for file in remote_files]
ds = xr.open_mfdataset(fileset, combine='by_coords')

ds
# Out:
# <xarray.Dataset>
# Dimensions:      (year: 14, pixel: 96668, period: 46)
# Coordinates:
#   * year         (year) float64 2.003e+03 2.004e+03 ... 2.015e+03 2.016e+03
# Dimensions without coordinates: pixel, period
# Data variables:
#     longitude    (year, pixel) float64 dask.array<chunksize=(1, 96668), meta=np.ndarray>
#     latitude     (year, pixel) float64 dask.array<chunksize=(1, 96668), meta=np.ndarray>
#     startjulday  (year, period) float64 dask.array<chunksize=(1, 46), meta=np.ndarray>
#     endjulday    (year, period) float64 dask.array<chunksize=(1, 46), meta=np.ndarray>
#     dms          (period, year, pixel) float64 dask.array<chunksize=(46, 1, 96668), meta=np.ndarray>

# %% [markdown]
# ## Interpolation on regular grid
#
# for plotting

# %%
from scipy.interpolate import griddata

def interGali(ds,var):
    '''
        Interploting data on a regular lat,lon grid
        grid is built from latitudes and the longitudes on the lowest latitude
        Input : 
            ds : xarray dataset with latitude, longitude and variable "var" to be interpolated. 
                var, lat,long must be 1d (ie. not depend on time)
            var : string name of variable
        Returns a xarray dataArray with the gridded variable and lat lon as coords
    '''
    
    # sorting according to latitudes
    lalo = pd.MultiIndex.from_arrays([ds.latitude.values, ds.longitude.values]).sortlevel(level=0)[0] 
    # get longitudes of lowest latitude
    lowlat = lalo.values[0][0]
    lon1d = np.array([x[1] for x in lalo.values if x[0]==lowlat])
    # get latitudes
    lat1d = np.unique(ds.latitude.values)
    # Building regular grid of lat and lon
    lon, lat = np.meshgrid(lon1d,lat1d)

    # interpolation
    var_gridded =griddata(
            (ds.longitude.values, ds.latitude.values), #points
            ds[var].values, #data
            (lon, lat), #grid on which to interpolate
            method='nearest')
    
    return  xr.DataArray(
        var_gridded,
        dims=("lat","lon"),
        coords={
            "lat": lat1d,
            "lon": lon1d
        }
    )

# %%
dms_gridded = interGali(ds.isel(period=2,year=0), 'dms')
dms_gridded
# Out:
# <xarray.DataArray (lat: 180, lon: 1016)>
# array([[0.41543231, 0.38222325, 0.3671242 , ..., 0.49141684, 0.56497659,
#         0.51523982],
#        [0.41404938, 0.42319274, 0.45434336, ..., 0.44886694, 0.60731933,
#         0.41705671],
#        [0.41073834, 0.40242421, 0.39524111, ..., 0.35691034, 0.46582392,
#         0.4147866 ],
#        ...,
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan]])
# Coordinates:
#   * lat      (lat) float64 45.12 45.38 45.62 45.88 ... 89.12 89.38 89.62 89.88
#   * lon      (lon) float64 -179.8 -179.5 -179.1 -178.8 ... 179.1 179.5 179.8

# %% [markdown]
# ## Plots

# %%
fig, ax = plt.subplots(figsize=(8,8),
                       subplot_kw={'projection':ccrs.NorthPolarStereo()}
                       # subplot_kw={'projection':ccrs.PlateCarree()
                                  )

dms_gridded.plot.pcolormesh( 
    ax = ax,
    cbar_kwargs={ 'orientation':'vertical', 'shrink':.8},
    transform=ccrs.PlateCarree(),
    robust=True
)


ax.gridlines(draw_labels=True)
ax.coastlines()
fig.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(8,8),
                       subplot_kw={'projection':ccrs.NorthPolarStereo()}
                       # subplot_kw={'projection':ccrs.PlateCarree()
                                  )

pl=ax.pcolormesh(lon,lat,dms_gridded,
    vmin=0,vmax=10,
    transform=ccrs.PlateCarree(),
    # transform=ccrs.AlbersEqualArea(),
        )
fig.colorbar(pl,shrink=0.3)
ax.gridlines(draw_labels=True)
ax.coastlines()
fig.tight_layout()

# %% [markdown]
# ## Rounding

# %%
##sorting according to latitudes
# lalo = pd.MultiIndex.from_arrays([ds.latitude.values, ds.longitude.values]).sortlevel(level=0)[0] 
## get longitudes of lowest latitude
# lowlat = lalo.values[0][0]
# lons = np.array([x[1] for x in lalo.values if x[0]==lowlat])
# lons.size
# Out:
# 1016

# %%
# ## round longitudes to those of lowest latitude
# def find_nearest(array, value):
#     idx = (np.abs(array - value)).argmin()
#     return array[idx]

# for ip in range(ds.pixel.size):
#     # if ip%1002==0:
#         # print(ds['longitude'].values[ip] , find_nearest(lons,ds['longitude'].values[ip]) )
#     ds['longitude'][ip]= find_nearest(lons,ds['longitude'].values[ip])

# %%
np.unique(ds['longitude'].values).size
# Out:
# 91637

# %%
#### change coordinate from pixel (1d) to lat lon (2d)

### DOES NOT WORK : grid is not structured and rounding longitude will lead to superposing pixels tw0 pixel on same point
# lalo = pd.MultiIndex.from_arrays([ds.latitude.values, ds.longitude.values.round()],names=["lat", "lon"])

lalo = pd.MultiIndex.from_arrays([ds.latitude.values, ds.longitude.values],names=["lat", "lon"])
# lalo.sortlevel(level=0)
##checking for duplicates
m = np.zeros_like(lalo, dtype=bool)
m[np.unique(lalo, return_index=True)[1]] = True
lalo[~m]
# Out:
# MultiIndex([], names=['lat', 'lon'])

# %%
# 
ds=ds.assign_coords({ "pixel": lalo }).unstack("pixel")
ds#.sel(lat=45.125)

# %% [markdown]
# ## Sin Projection

# %%
def sinProj(lat,lon):
    # x=lon*np.cos(lat*np.pi/180)
    # y=lat
    x=lon/np.cos(lat*np.pi/180)
    y=lat
    return x,y

ds['x'],ds['y'] = sinProj(ds.latitude,ds.longitude)
# ds
# np.unique(ds.x.values.round()).size

# %%
#### change coordinate from pixel (1d) to lat lon (2d)

yx = pd.MultiIndex.from_arrays([ds.y.values, ds.x.values.round()],names=["y", "x"])
# yx.sortlevel(level=1)

##checking for duplicates
# m = np.zeros_like(yx, dtype=bool)
# m[np.unique(yx, return_index=True)[1]] = True
# yx[~m]

# %%
ds=ds.assign_coords({ "pixel": yx }).unstack("pixel")
ds#.sel(lat=45.125)
# Out:
# <xarray.Dataset>
# Dimensions:      (y: 180, x: 3319, year: 1, period: 46)
# Coordinates:
#   * y            (y) float64 45.12 45.38 45.62 45.88 ... 89.12 89.38 89.62 89.88
#   * x            (x) float64 -5.5e+04 -2.445e+04 ... 2.445e+04 5.5e+04
#   * year         (year) float64 2.01e+03
# Dimensions without coordinates: period
# Data variables:
#     longitude    (y, x) float64 nan nan nan nan nan ... nan nan nan nan 120.0
#     latitude     (y, x) float64 nan nan nan nan nan ... nan nan nan nan 89.88
#     startjulday  (period) float64 1.0 9.0 17.0 25.0 ... 337.0 345.0 353.0 361.0
#     endjulday    (period) float64 8.0 16.0 24.0 32.0 ... 344.0 352.0 360.0 365.0
#     dms          (period, year, y, x) float64 nan nan nan nan ... nan nan nan
